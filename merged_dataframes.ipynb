# %%
import scraping_functions as sf
import pandas as pd

# %%
nofluffjobs_list = sf.nofluffjobs_page_job_offers()
df_raw_1 = pd.DataFrame.from_records(nofluffjobs_list)
df_1 = df_raw_1.copy()
if len(df_1) != 0:
    df_1['publication_date'] = pd.to_datetime(df_1['publication_date'], infer_datetime_format=True)
    df_1.drop_duplicates(subset=['publication_date', 'company', 'title'], inplace=True, ignore_index=True)

# %%
df_1
# Out:
#   publication_date                                            company  \
# 0       2022-08-25                                             Devire
# 1       2022-08-18                          Amartus Polska Sp. z o.o.
# 2       2022-08-18  IDEA team within Narodowe Centrum Badań Jądrowych
# 3       2022-08-26                                       Webinterpret
# 4       2022-08-23          Sport Vision Technology sp. z o.o. sp. k.
# 5       2022-08-20                                  Deloitte Advisory
# 6       2022-08-27                                      Astrotectonic
#
#                              title position                  website  \
# 0  Python Developer (Data Science)   Junior  https://nofluffjobs.com
# 1          Junior Phyton Developer   Junior  https://nofluffjobs.com
# 2          Junior Python Developer   Junior  https://nofluffjobs.com
# 3            Junior Data Scientist   Junior  https://nofluffjobs.com
# 4              Junior AI Developer   Junior  https://nofluffjobs.com
# 5                           AI LAB  Trainee  https://nofluffjobs.com
# 6            Junior Data Scientist   Junior  https://nofluffjobs.com
#
#                                             link_url
# 0  https://nofluffjobs.com/pl/job/python-develope...
# 1  https://nofluffjobs.com/pl/job/junior-phyton-d...
# 2  https://nofluffjobs.com/pl/job/junior-python-d...
# 3  https://nofluffjobs.com/pl/job/junior-data-sci...
# 4  https://nofluffjobs.com/pl/job/junior-ai-devel...
# 5  https://nofluffjobs.com/pl/job/ai-lab-deloitte...
# 6  https://nofluffjobs.com/pl/job/junior-data-sci...

# %%
bulldogjob_list = sf.bulldog_page_job_offers()
df_raw_2 = pd.DataFrame.from_records(bulldogjob_list)
df_2 = df_raw_2.copy()
df_2['publication_date'] = pd.to_datetime(df_2['publication_date'], infer_datetime_format=True)
df_2.drop_duplicates(subset=['publication_date', 'company', 'title'], inplace=True, ignore_index=True)

# %%
df_2
# Out:
#   publication_date           company  \
# 0       2022-08-02  Accenture Polska
#
#                                                title position  \
# 0  Junior Data Engineer with Python (Communicatio...   Junior
#
#                  website                                           link_url
# 0  https://bulldogjob.pl  https://bulldogjob.pl/companies/jobs/120362-ju...

# %%
df_3 = pd.concat([df_1, df_2], axis=0, ignore_index=True)
df_3.sort_values(['publication_date'], inplace=True, ascending=False)

# %%
df_3.reset_index(drop=True)
df_3.sort_values('publication_date',ascending=False)
# Out:
#   publication_date                                            company  \
# 6       2022-08-27                                      Astrotectonic
# 3       2022-08-26                                       Webinterpret
# 0       2022-08-25                                             Devire
# 4       2022-08-23          Sport Vision Technology sp. z o.o. sp. k.
# 5       2022-08-20                                  Deloitte Advisory
# 1       2022-08-18                          Amartus Polska Sp. z o.o.
# 2       2022-08-18  IDEA team within Narodowe Centrum Badań Jądrowych
# 7       2022-08-02                                   Accenture Polska
#
#                                                title position  \
# 6                              Junior Data Scientist   Junior
# 3                              Junior Data Scientist   Junior
# 0                    Python Developer (Data Science)   Junior
# 4                                Junior AI Developer   Junior
# 5                                             AI LAB  Trainee
# 1                            Junior Phyton Developer   Junior
# 2                            Junior Python Developer   Junior
# 7  Junior Data Engineer with Python (Communicatio...   Junior
#
#                    website                                           link_url
# 6  https://nofluffjobs.com  https://nofluffjobs.com/pl/job/junior-data-sci...
# 3  https://nofluffjobs.com  https://nofluffjobs.com/pl/job/junior-data-sci...
# 0  https://nofluffjobs.com  https://nofluffjobs.com/pl/job/python-develope...
# 4  https://nofluffjobs.com  https://nofluffjobs.com/pl/job/junior-ai-devel...
# 5  https://nofluffjobs.com  https://nofluffjobs.com/pl/job/ai-lab-deloitte...
# 1  https://nofluffjobs.com  https://nofluffjobs.com/pl/job/junior-phyton-d...
# 2  https://nofluffjobs.com  https://nofluffjobs.com/pl/job/junior-python-d...
# 7    https://bulldogjob.pl  https://bulldogjob.pl/companies/jobs/120362-ju...
