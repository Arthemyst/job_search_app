# %%
import scraping_functions as sf
import pandas as pd

# %%
nofluffjobs_list = sf.nofluffjobs_page_job_offers()
df_raw_1 = pd.DataFrame.from_records(nofluffjobs_list)
df_1 = df_raw_1.copy()
df_1['publication_date'] = pd.to_datetime(df_1['publication_date'], infer_datetime_format=True)
df_1.drop_duplicates(subset=['publication_date', 'company', 'title'], inplace=True, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/pawel/job_search_app/merged_dataframes.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pawel/job_search_app/merged_dataframes.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> nofluffjobs_list = sf.nofluffjobs_page_job_offers()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pawel/job_search_app/merged_dataframes.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> df_raw_1 = pd.DataFrame.from_records(nofluffjobs_list)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/pawel/job_search_app/merged_dataframes.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> df_1 = df_raw_1.copy()
#
# File ~/job_search_app/scraping_functions.py:68, in nofluffjobs_page_job_offers()
#      66 position = soup_page.find("span", class_="mr-10 font-weight-medium")
#      67 publication_date_element = soup_page.find("div", class_="posting-time-row")
# ---> 68 days_after_publication = int(re.findall(r'\b\d+\b', publication_date_element.text.strip())[0])
#      69 publication_date = (datetime.today() - (timedelta(days=days_after_publication))).strftime("%Y-%m-%d")
#      70 #creation of job offers details dictionary
#
# IndexError: list index out of range

# %%
df_1
# Out:
#   publication_date                                            company  \
# 0       2022-08-18                          Amartus Polska Sp. z o.o.
# 1       2022-08-18  IDEA team within Narodowe Centrum Badań Jądrowych
# 2       2022-08-18                                             Devire
# 3       2022-08-20                                  Deloitte Advisory
# 4       2022-08-19                                       Webinterpret
# 5       2022-08-08          Sport Vision Technology sp. z o.o. sp. k.
# 6       2022-08-17                                      Astrotectonic
#
#                              title position  \
# 0          Junior Phyton Developer   Junior
# 1          Junior Python Developer   Junior
# 2  Python Developer (Data Science)   Junior
# 3                           AI LAB  Trainee
# 4            Junior Data Scientist   Junior
# 5              Junior AI Developer   Junior
# 6            Junior Data Scientist   Junior
#
#                                             link_url
# 0  http://nofluffjobs.com/pl/job/junior-phyton-de...
# 1  http://nofluffjobs.com/pl/job/junior-python-de...
# 2  http://nofluffjobs.com/pl/job/python-developer...
# 3  http://nofluffjobs.com/pl/job/ai-lab-deloitte-...
# 4  http://nofluffjobs.com/pl/job/junior-data-scie...
# 5  http://nofluffjobs.com/pl/job/junior-ai-develo...
# 6  http://nofluffjobs.com/pl/job/junior-data-scie...

# %%
bulldogjob_list = sf.bulldog_page_job_offers()
df_raw_2 = pd.DataFrame.from_records(bulldogjob_list)
df_2 = df_raw_2.copy()
df_2['publication_date'] = pd.to_datetime(df_2['publication_date'], infer_datetime_format=True)
df_2.drop_duplicates(subset=['publication_date', 'company', 'title'], inplace=True, ignore_index=True)

# %%
df_2
# Out:
#   publication_date            company  \
# 0       2022-07-23   Accenture Polska
# 1       2022-08-14  Bertek Sp. z o.o.
#
#                                                title position  \
# 0  Junior Data Engineer with Python (Communicatio...   Junior
# 1                            Junior Python Developer   Junior
#
#                                             link_url
# 0  https://bulldogjob.pl/companies/jobs/120362-ju...
# 1  https://bulldogjob.pl/companies/jobs/113373-ju...

# %%
df_3 = pd.concat([df_1, df_2], axis=0, ignore_index=True)
df_3.sort_values(['publication_date'], inplace=True, ascending=False)

# %%
df_3
# Out:
#   publication_date                                            company  \
# 3       2022-08-20                                  Deloitte Advisory
# 4       2022-08-19                                       Webinterpret
# 0       2022-08-18                          Amartus Polska Sp. z o.o.
# 1       2022-08-18  IDEA team within Narodowe Centrum Badań Jądrowych
# 2       2022-08-18                                             Devire
# 6       2022-08-17                                      Astrotectonic
# 8       2022-08-14                                  Bertek Sp. z o.o.
# 5       2022-08-08          Sport Vision Technology sp. z o.o. sp. k.
# 7       2022-07-23                                   Accenture Polska
#
#                                                title position  \
# 3                                             AI LAB  Trainee
# 4                              Junior Data Scientist   Junior
# 0                            Junior Phyton Developer   Junior
# 1                            Junior Python Developer   Junior
# 2                    Python Developer (Data Science)   Junior
# 6                              Junior Data Scientist   Junior
# 8                            Junior Python Developer   Junior
# 5                                Junior AI Developer   Junior
# 7  Junior Data Engineer with Python (Communicatio...   Junior
#
#                                             link_url
# 3  http://nofluffjobs.com/pl/job/ai-lab-deloitte-...
# 4  http://nofluffjobs.com/pl/job/junior-data-scie...
# 0  http://nofluffjobs.com/pl/job/junior-phyton-de...
# 1  http://nofluffjobs.com/pl/job/junior-python-de...
# 2  http://nofluffjobs.com/pl/job/python-developer...
# 6  http://nofluffjobs.com/pl/job/junior-data-scie...
# 8  https://bulldogjob.pl/companies/jobs/113373-ju...
# 5  http://nofluffjobs.com/pl/job/junior-ai-develo...
# 7  https://bulldogjob.pl/companies/jobs/120362-ju...
